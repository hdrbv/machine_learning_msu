# %% [markdown]
# # Final Challenge — Linear Regression + Categorical Encoding
#
# ## Business problem
#
# Хотим построить бизнес на покупке/перепродаже недооцененных машин
#
# Датасет реальных предложений продажи подержаных машин с drom
# Ваша задача — построить и проверить linear regression model.

# %% [markdown]
# | Столбец | Описание |
# |---|---|
# | `listing_id` | Уникальный идентификатор объявления на Drom. |
# | `brand` | Марка автомобиля: BMW, Chery, Lada и т. д. |
# | `brand_group` | Группа марки: `Europe`, `China`, `Russia`. |
# | `brand_country` | Страна происхождения марки, а не сборки автомобиля. |
# | `model` | Модель автомобиля, например Tiguan. |
# | `year` | Год выпуска. |
# | `engine_volume_l` | Объём двигателя в литрах. |
# | `power_hp` | Мощность двигателя в лошадиных силах. |
# | `fuel_type` | Тип топлива или силовой установки: бензин, дизель, гибрид, электро и т. д. |
# | `transmission` | Коробка передач: механика, АКПП, робот, вариатор. |
# | `drive` | Привод: передний, задний, `4WD` — полный. |
# | `mileage_km` | Пробег в километрах. |
# | `body_type` | Тип кузова: седан, хэтчбек, внедорожник и т. д. |
# | `trim` | Модификация и комплектация, указанные в объявлении. |
# | `city` | Город объявления: Москва или Санкт-Петербург. |
# | `price_rub` | **Цена предложения продавца в рублях**. Фактическая сумма сделки неизвестна. |
# | `price_type` | Тип цены: `asking_price` — запрашиваемая продавцом цена. |
# | `condition` | Категория автомобиля: `used` — с пробегом. |
# | `is_damaged` | `1` — есть отметка о повреждении; `0` — такой отметки нет. Ноль не гарантирует отсутствие повреждений. |
# | `labels` | Дополнительные отметки Drom, например «от собственника», «без пробега по РФ». |
# | `attributes_raw` | Исходный текст характеристик из выдачи Drom. |
# | `source_url` | Ссылка на конкретное объявление. |
# | `search_url` | Страница выдачи, с которой скачано объявление. |
# | `collected_at_utc` | Дата и время скачивания страницы в UTC, а не дата публикации объявления. |
# | `model_rank` | Место модели внутри марки: от 1 до 5 по суммарному числу объявлений с пробегом в двух городах на момент отбора. |
# | `model_id` | Идентификатор модели в каталоге Drom. |

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, root_mean_squared_error, mean_absolute_percentage_error, r2_score

df = pd.read_csv("../data/drom_used_cars.csv")
df.head(3)
# Out:
#    listing_id       brand brand_group brand_country   model  year  \
# 0   327415747  Volkswagen      Europe       Germany  Tiguan  2021
# 1   312658259  Volkswagen      Europe       Germany  Tiguan  2021
# 2   758058921  Volkswagen      Europe       Germany  Tiguan  2012
#
#    engine_volume_l  power_hp fuel_type transmission  ...    price_type  \
# 0              2.0     180.0    бензин        робот  ...  asking_price
# 1              2.0     180.0    бензин        робот  ...  asking_price
# 2              2.0     170.0    бензин         АКПП  ...  asking_price
#
#    condition is_damaged           labels  \
# 0       used          0              NaN
# 1       used          0              NaN
# 2       used          0  от собственника
#
#                                       attributes_raw  \
# 0  2.0 л (180 л.с.) | бензин | робот | 4WD | 70 0...
# 1  2.0 л (180 л.с.) | бензин | робот | 4WD | 88 8...
# 2  2.0 л (170 л.с.) | бензин | АКПП | 4WD | 226 0...
#
#                                           source_url  \
# 0  https://auto.drom.ru/moscow/volkswagen/tiguan/...
# 1  https://auto.drom.ru/spb/volkswagen/tiguan/312...
# 2  https://auto.drom.ru/moscow/volkswagen/tiguan/...
#
#                                           search_url  \
# 0  https://auto.drom.ru/moscow/volkswagen/tiguan/...
# 1   https://auto.drom.ru/spb/volkswagen/tiguan/used/
# 2  https://auto.drom.ru/moscow/volkswagen/tiguan/...
#
#                    collected_at_utc  model_rank model_id
# 0  2026-09-18T08:36:30.751519+00:00           1     3711
# 1  2026-09-18T08:36:32.512797+00:00           1     3711
# 2  2026-09-18T08:36:30.751519+00:00           1     3711
#
# [3 rows x 26 columns]

# %% [markdown]
# ## Task 1 — Understand the data
#
# Ответьте:
# 1. What is the unit of observation?
# 2. What is the target?
# 3. Какие признаки numerical?
# 4. Какие categorical?
# 5. Какие потенциальные data-quality issues вы хотите проверить?

# %%
df.shape
# Out:
# (8709, 26)

# %% [markdown]
# ## Task 2 — EDA
#
# Проведите минимальный EDA:
# - distributions;
# - missing values;
# - unusual observations;
# - correlations among numerical features;
# - target by categorical groups.
#
# **Не удаляйте наблюдения автоматически только потому, что они выглядят необычно.**

# %%
# your code here

# %% [markdown]
# ## Task 3 — Train/test split
#
# Сделайте train/test split до любых преобразований, использующих target.

# %%
# your code here

# %% [markdown]
# ## Task 4 — Baseline model
#
# Постройте baseline linear regression только на numerical features.
#
# Оцените:
# - MAE;
# - RMSE;
# - MAPE;
# - R².

# %%
# your code here

# %% [markdown]
# ## Task 5 — Add categorical features
#
# Выберите encoding и обоснуйте выбор.
#
# Минимум попробуйте:
# - One-hot encoding;
# - еще один способ кодирования по вашему выбору.
#
# (Frequency encoding,
#  Target encoding,
# Out-of-fold target encoding)
#
# Сравните test metrics.

# %%
# your code here

# %% [markdown]
# ## Task 6 — Investigate model errors
#
# Проверьте:
# - residual pattern;
# - outliers;
# - где модель ошибается сильнее всего;
# - зависит ли ошибка от salary level;
# - есть ли systematic differences by industry/city.

# %%
# your code here

# %% [markdown]
# ## Task 9 — Interpretation
